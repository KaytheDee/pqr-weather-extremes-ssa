# %%
import pandas as pd
import numpy as np 
import geopandas as gpd 
import matplotlib.pyplot as plt 
from matplotlib.colors import ListedColormap
from sklearn.decomposition import PCA
import seaborn as sns 
from scipy.stats import pearsonr
import json
from shapely.geometry import shape 
# from shapely.geometry import Polygon 
import json 
from shapely import wkt 
from shapely.geometry import Point
import plotly.express as px
from pandas.tseries.offsets import Week
from statsmodels.tsa.stattools import kpss 
import statsmodels.api as sm
import warnings
import scipy.stats as stats
from scipy.stats import zscore

# %% [markdown]
# ## Legon

# %%
### Precip 
legon_precip_hourly = pd.read_excel('/Users/kwamedonkor/Downloads/UW/Research/Quals/Output_Files/Precip/legon_final_hr_resampled_v2.xlsx')

### Temp 
legon_temp_hourly = pd.read_excel('/Users/kwamedonkor/Downloads/UW/Research/Quals/Output_Files/Temp/legon_final_hr_resampled_v2.xlsx')

### Merging Precip and Temp 
legon_merged = pd.merge(legon_precip_hourly, legon_temp_hourly, on = 'Hour', how = 'inner')

# %% [markdown]
# ## St_Johns

# %%
### Precip 
st_johns_precip_hourly = pd.read_excel('/Users/kwamedonkor/Downloads/UW/Research/Quals/Output_Files/Precip/st_johns_final_hr_resampled_v2.xlsx')

### Temp 
st_johns_temp_hourly = pd.read_excel('/Users/kwamedonkor/Downloads/UW/Research/Quals/Output_Files/Temp/st_johns_final_hr_resampled_v2.xlsx')

### Merging Precip and Temp 
st_johns_merged = pd.merge(st_johns_precip_hourly, st_johns_temp_hourly, on = 'Hour', how = 'inner')

# %% [markdown]
# ## Accra_Aca

# %%
accra_aca_precip_hourly = pd.read_excel('/Users/kwamedonkor/Downloads/UW/Research/Quals/Output_Files/Precip/accra_aca_final_hr_resampled_v2.xlsx')

accra_aca_temp_hourly = pd.read_excel('/Users/kwamedonkor/Downloads/UW/Research/Quals/Output_Files/Temp/accra_aca_final_hr_resampled_v2.xlsx')

accra_aca_merged = pd.merge(accra_aca_precip_hourly, accra_aca_temp_hourly, on = 'Hour', how = 'inner')

# %% [markdown]
# ## G_Met

# %% [markdown]
# #### Precip Hourly

# %%
g_met_precip_hourly = pd.read_excel('/Users/kwamedonkor/Downloads/UW/Research/Quals/Output_Files/Precip/g_met_hq_final_hr_resampled_v2.xlsx')

g_met_temp_hourly = pd.read_excel('/Users/kwamedonkor/Downloads/UW/Research/Quals/Output_Files/Temp/g_met_hq_final_hr_resampled_v2.xlsx')

g_met_merged = pd.merge(g_met_precip_hourly, g_met_temp_hourly, on = 'Hour', how = 'inner')

# %% [markdown]
# ## Temasco

# %%
temasco_precip_hourly = pd.read_excel('/Users/kwamedonkor/Downloads/UW/Research/Quals/Output_Files/Precip/temasco_final_hr_resampled_v2.xlsx')

temasco_temp_hourly = pd.read_excel('/Users/kwamedonkor/Downloads/UW/Research/Quals/Output_Files/Temp/temasco_final_hr_resampled_v2.xlsx')

temasco_merged = pd.merge(temasco_precip_hourly, temasco_temp_hourly, on = 'Hour', how = 'inner')

# %% [markdown]
# ## Safisana

# %%
safisana_precip_hourly = pd.read_excel('/Users/kwamedonkor/Downloads/UW/Research/Quals/Output_Files/Precip/safisana_final_hr_resampled_v2.xlsx')

safisana_temp_hourly = pd.read_excel('/Users/kwamedonkor/Downloads/UW/Research/Quals/Output_Files/Temp/safisana_final_hr_resampled_v2.xlsx')

safisana_merged = pd.merge(safisana_precip_hourly, safisana_temp_hourly, on = 'Hour', how = 'inner')

# %% [markdown]
# ## Nsawam

# %%
nsawam_precip_hourly = pd.read_excel('/Users/kwamedonkor/Downloads/UW/Research/Quals/Output_Files/Precip/nsawam_final_hr_resampled_v2.xlsx')

nsawam_temp_hourly = pd.read_excel('/Users/kwamedonkor/Downloads/UW/Research/Quals/Output_Files/Temp/nsawam_final_hr_resampled_v2.xlsx')

nsawam_merged = pd.merge(nsawam_precip_hourly, nsawam_temp_hourly, on = 'Hour', how = 'inner')

# %% [markdown]
# ## Agri Impact

# %% [markdown]
# #### Precip Hourly

# %%
agri_impact_precip_hourly = pd.read_excel('/Users/kwamedonkor/Downloads/UW/Research/Quals/Output_Files/Precip/agri_impact_final_hr_resampled_v2.xlsx')

agri_impact_temp_hourly = pd.read_excel('/Users/kwamedonkor/Downloads/UW/Research/Quals/Output_Files/Temp/agri_impact_final_hr_resampled_v2.xlsx')

agri_impact_merged = pd.merge(agri_impact_precip_hourly, agri_impact_temp_hourly, on = 'Hour', how = 'inner')

# %% [markdown]
# ## Accra Girls

# %% [markdown]
# #### Precip Hourly

# %%
accra_girls_hourly = pd.read_excel('/Users/kwamedonkor/Downloads/UW/Research/Quals/Output_Files/Precip/accra_girls_final_hr_resampled_v2.xlsx')

accra_girls_temp_hourly = pd.read_excel('/Users/kwamedonkor/Downloads/UW/Research/Quals/Output_Files/Temp/accra_girls_final_hr_resampled_v2.xlsx')

accra_girls_merged = pd.merge(accra_girls_hourly, accra_girls_temp_hourly, on = 'Hour', how = 'inner')

# %% [markdown]
# ## Madina

# %% [markdown]
# #### Precip Hourly

# %%
madina_precip_hourly = pd.read_excel('/Users/kwamedonkor/Downloads/UW/Research/Quals/Output_Files/Precip/madina_final_hr_resampled_v2.xlsx')

madina_temp_hourly = pd.read_excel('/Users/kwamedonkor/Downloads/UW/Research/Quals/Output_Files/Temp/madina_final_hr_resampled_v2.xlsx')

madina_merged = pd.merge(madina_precip_hourly, madina_temp_hourly, on = 'Hour', how = 'inner')

# %% [markdown]
# ## Berekuso

# %%
berekuso_precip_hourly = pd.read_excel('/Users/kwamedonkor/Downloads/UW/Research/Quals/Output_Files/Precip/berekuso_final_hr_resampled_v2.xlsx')

berekuso_temp_hourly = pd.read_excel('/Users/kwamedonkor/Downloads/UW/Research/Quals/Output_Files/Temp/berekuso_final_hr_resampled_v2.xlsx')

berekuso_merged = pd.merge(berekuso_precip_hourly, berekuso_temp_hourly, on = 'Hour', how = 'inner')

# %% [markdown]
# ### Rename Columns

# %%
def rename_weather_df(df, location_name):
    df = df.copy()
    rename_dict = {}

    # Dynamically rename columns containing 'Interpol_Precip_' and 'Interpol_Temp_'
    for col in df.columns:
        if 'Interpol_Precip_' in col:
            rename_dict[col] = 'Interpol_Precip'
        if 'Interpol_Temp_' in col:
            rename_dict[col] = 'Interpol_Temp'

    df.rename(columns=rename_dict, inplace=True)
    df['Location'] = location_name
    return df

# %%
### Rename dfs 

legon_merged_r1 = rename_weather_df(legon_merged, 'Legon')
st_johns_merged_r1 = rename_weather_df(st_johns_merged, 'St_Johns')
accra_aca_merged_r1 = rename_weather_df(accra_aca_merged, 'Accra_Aca')
g_met_merged_r1 = rename_weather_df(g_met_merged, 'G_Met')
temasco_merged_r1 = rename_weather_df(temasco_merged, 'Temasco')
safisana_merged_r1 = rename_weather_df(safisana_merged, 'Safisana')
nsawam_merged_r1 = rename_weather_df(nsawam_merged, 'Nsawam')
agri_impact_merged_r1 = rename_weather_df(agri_impact_merged, 'Agri_Impact')
accra_girls_merged_r1 = rename_weather_df(accra_girls_merged, 'Accra_Girls')
madina_merged_r1 = rename_weather_df(madina_merged, 'Madina')
berekuso_merged_r1 = rename_weather_df(berekuso_merged, 'Berekuso')


### Concatenate dfs 

weather_concat = pd.concat([
    legon_merged_r1, 
    st_johns_merged_r1, 
    accra_aca_merged_r1, 
    g_met_merged_r1, 
    temasco_merged_r1, 
    safisana_merged_r1, 
    nsawam_merged_r1, 
    agri_impact_merged_r1, 
    accra_girls_merged_r1, 
    madina_merged_r1, 
    berekuso_merged_r1
])

# weather_concat.to_csv('/Users/kwamedonkor/Downloads/UW/Research/Quals/Output_Files/weather_concat.csv')

# %% [markdown]
# ## Variable comparison of weather stations in close proximity

# %%
def resample_and_plot_temp_multi(df1, df2=None, df3=None, freq='D', title='Temperature Over Time', labels=None):

    def prepare(df):
        df = df.copy()
        df['Hour'] = pd.to_datetime(df['Hour'])
        df.set_index('Hour', inplace=True)
        return df['Interpol_Temp'].resample(freq).mean()

    # Prepare and collect all valid DataFrames
    series_list = [prepare(df1)]
    if df2 is not None:
        series_list.append(prepare(df2))
    if df3 is not None:
        series_list.append(prepare(df3))

    if labels is None:
        labels = [f"Dataset {i+1}" for i in range(len(series_list))]

    # Plot
    plt.figure(figsize=(14, 6))
    for series, label in zip(series_list, labels):
        series.plot(label=label)

    plt.title(title)
    plt.xlabel('Date' if freq == 'D' else 'Month')
    plt.ylabel('Average Temperature (°C)', labelpad=10)
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    return

# %%
def resample_and_plot_precip_multi(df1, df2=None, df3=None, freq='D', title='Precipitation Over Time', labels=None):

    def prepare(df):
        df = df.copy()
        df['Hour'] = pd.to_datetime(df['Hour'])
        df.set_index('Hour', inplace=True)
        return df['Interpol_Precip'].resample(freq).sum()

    # Prepare and collect all valid DataFrames
    series_list = [prepare(df1)]
    if df2 is not None:
        series_list.append(prepare(df2))
    if df3 is not None:
        series_list.append(prepare(df3))

    if labels is None:
        labels = [f"Dataset {i+1}" for i in range(len(series_list))]

    # Plot
    plt.figure(figsize=(14, 6))
    for series, label in zip(series_list, labels):
        series.plot(label=label)

    plt.title(title)
    plt.xlabel('Date' if freq == 'D' else 'Month')
    plt.ylabel('Total Precipitation', labelpad = 10)
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    return

# %%
def print_precip_stats(df, column='Interpol_Precip'):
    mean_val = df[column].mean()
    std_val = df[column].std()
    print(f"Mean of {column}: {mean_val:.2f}")
    print(f"Standard Deviation of {column}: {std_val:.2f}")

# %%
def calc_precip_corr(df1, df2, column='Interpol_Precip'):
    common_index = df1.index.intersection(df2.index)
    series1 = df1.loc[common_index, column]
    series2 = df2.loc[common_index, column]
    corr = series1.corr(series2)
    print(f"Correlation between {column} in the two DataFrames: {corr:.3f}")
    return

# %%
from scipy.stats import ttest_ind

def run_ttest(df1, df2, column='Interpol_Precip', label1='DF1', label2='DF2'):

    # Drop NaNs to ensure clean comparison
    x = df1[column].dropna()
    y = df2[column].dropna()

    # Run Welch’s t-test (doesn't assume equal variance)
    t_stat, p_val = ttest_ind(x, y, equal_var=False)

    print(f"t-test comparing {label1} and {label2} on '{column}':")
    print(f"  t-statistic: {t_stat:.3f}")
    print(f"  p-value: {p_val:.3f}")

    if p_val < 0.05:
        print("  ✅ Statistically significant difference in means.")
    else:
        print("  ❌ No statistically significant difference in means.")

    return

# %%
def calc_precip_corr_three(df1, df2, df3, column='Interpol_Precip'):
    # Find common index across all three
    common_index = df1.index.intersection(df2.index).intersection(df3.index)

    # Extract aligned series
    s1 = df1.loc[common_index, column]
    s2 = df2.loc[common_index, column]
    s3 = df3.loc[common_index, column]

    # Compute pairwise correlations
    corr_12 = s1.corr(s2)
    corr_13 = s1.corr(s3)
    corr_23 = s2.corr(s3)

    # Print results
    print(f"Correlation between df1 and df2: {corr_12:.3f}")
    print(f"Correlation between df1 and df3: {corr_13:.3f}")
    print(f"Correlation between df2 and df3: {corr_23:.3f}")

    return

# %% [markdown]
# #### Agri_Impact & Berekuso

# %%
agri_impact_merged_r1_copy = agri_impact_merged_r1.copy()
agri_impact_merged_r1_copy = agri_impact_merged_r1_copy.set_index('Hour').loc['2022-01-01':'2022-12-09'].reset_index()

berekuso_merged_r1_copy = berekuso_merged_r1.copy()
berekuso_merged_r1_copy = berekuso_merged_r1_copy.set_index('Hour').loc['2022':'2023'].reset_index()

### Remove outliers 

hours = ['2022-05-06 16:00:00', '2022-05-06 17:00:00']

agri_impact_merged_r1_copy = agri_impact_merged_r1_copy[~(agri_impact_merged_r1_copy['Hour'].isin(hours))].reset_index()

# %%
## Distance between them: 
# Agri_Impact and Berekuso: 1.08km

# %%
resample_and_plot_precip_multi(
    df1=berekuso_merged_r1_copy,
    df2=agri_impact_merged_r1_copy,
    freq='D',
    title='Daily Rainfall Comparison - Berekuso and Agri_Impact',
    labels=['Berekuso', 'Agri_Impact']
)

# %%
print_precip_stats(berekuso_merged_r1_copy)
print("")
print_precip_stats(agri_impact_merged_r1_copy)
# Out:
# Mean of Interpol_Precip: 0.11
# Standard Deviation of Interpol_Precip: 0.97
#
# Mean of Interpol_Precip: 0.09
# Standard Deviation of Interpol_Precip: 1.03

# %%
calc_precip_corr(berekuso_merged_r1_copy, agri_impact_merged_r1_copy)
# Out:
# Correlation between Interpol_Precip in the two DataFrames: 0.281

# %%
run_ttest(berekuso_merged_r1_copy, agri_impact_merged_r1_copy, column='Interpol_Precip', label1='Berekuso', label2='Agri_Impact')
# Out:
# t-test comparing Berekuso and Agri_Impact on 'Interpol_Precip':
#   t-statistic: 1.260
#   p-value: 0.208
#   ❌ No statistically significant difference in means.

# %%
resample_and_plot_temp_multi(
    df1=berekuso_merged_r1_copy,
    df2=agri_impact_merged_r1_copy,
    freq='D',
    title='Daily Temperature - Berekuso and Agri_Impact',
    labels=['Berekuso', 'Agri_Impact']
)

# %% [markdown]
# #### Madina, Legon, G_Met

# %%
madina_merged_r1_copy = madina_merged_r1.copy()
madina_merged_r1_copy = madina_merged_r1_copy.set_index('Hour').loc['2022':'2023-08-28'].reset_index()

legon_merged_r1_copy = legon_merged_r1.copy()
legon_merged_r1_copy = legon_merged_r1_copy.set_index('Hour').loc['2022':'2023-08-28'].reset_index()

g_met_merged_r1_copy = g_met_merged_r1.copy()
g_met_merged_r1_copy = g_met_merged_r1_copy.set_index('Hour').loc['2022':'2023'].reset_index()

# %%
## Distance between them: 
# Madina and Legon: 2.124 km 
# Madina and G_Met: 3.05 km 
# Legon and G_Met: 3.01 km

# %%
resample_and_plot_precip_multi(
    df1=madina_merged_r1_copy,
    df2=legon_merged_r1_copy,
    df3=g_met_merged_r1_copy,
    freq='D',
    title='Daily Rainfall Comparison - Madina, Legon, G_Met',
    labels=['Madina', 'Legon', 'G_Met']
)

# %%
print_precip_stats(madina_merged_r1_copy)
print("")
print_precip_stats(legon_merged_r1_copy)
print("")
print_precip_stats(g_met_merged_r1_copy)
# Out:
# Mean of Interpol_Precip: 0.09
# Standard Deviation of Interpol_Precip: 1.06
#
# Mean of Interpol_Precip: 0.06
# Standard Deviation of Interpol_Precip: 0.70
#
# Mean of Interpol_Precip: 0.11
# Standard Deviation of Interpol_Precip: 1.38

# %%
calc_precip_corr_three(madina_merged_r1_copy, legon_merged_r1_copy, g_met_merged_r1_copy)
# Out:
# Correlation between df1 and df2: 0.621
# Correlation between df1 and df3: 0.510
# Correlation between df2 and df3: 0.614

# %%
run_ttest(madina_merged_r1_copy, legon_merged_r1_copy, column='Interpol_Precip')
# Out:
# t-test comparing DF1 and DF2 on 'Interpol_Precip':
#   t-statistic: 2.368
#   p-value: 0.018
#   ✅ Statistically significant difference in means.

# %%
run_ttest(madina_merged_r1_copy, g_met_merged_r1_copy, column='Interpol_Precip')
# Out:
# t-test comparing DF1 and DF2 on 'Interpol_Precip':
#   t-statistic: -1.397
#   p-value: 0.162
#   ❌ No statistically significant difference in means.

# %%
run_ttest(legon_merged_r1_copy, g_met_merged_r1_copy, column='Interpol_Precip')
# Out:
# t-test comparing DF1 and DF2 on 'Interpol_Precip':
#   t-statistic: -3.454
#   p-value: 0.001
#   ✅ Statistically significant difference in means.

# %%
resample_and_plot_temp_multi(
    df1=madina_merged_r1_copy,
    df2=legon_merged_r1_copy,
    df3=g_met_merged_r1_copy,
    freq='D',
    title='Daily Temperature Comparison - Madina, Legon, G_Met',
    labels=['Madina', 'Legon', 'G_Met']
)

# %% [markdown]
# #### Accra_Aca, Accra_Girls, St_Johns

# %%
accra_aca_merged_r1_copy = accra_aca_merged_r1.copy()
accra_aca_merged_r1_copy = accra_aca_merged_r1_copy.set_index('Hour').loc['2022':'2023'].reset_index()

accra_girls_merged_r1_copy = accra_girls_merged_r1.copy()
accra_girls_merged_r1_copy = accra_girls_merged_r1_copy.set_index('Hour').loc['2022':'2023-07-12'].reset_index()

st_johns_merged_r1_copy = st_johns_merged_r1.copy()
st_johns_merged_r1_copy = st_johns_merged_r1_copy.set_index('Hour').loc['2022':'2023-07-12'].reset_index()

# %%
## Distance between them: 
# Accra_Aca and Accra_Girls: 6.17 km
# Accra_Aca and St_Johns: 7.22 km 
# Accra_Girls and St_Johns: 7.23 km

# %%
resample_and_plot_precip_multi(
    df1=accra_aca_merged_r1_copy,
    df2=accra_girls_merged_r1_copy,
    df3=st_johns_merged_r1_copy,
    freq='D',
    title='Daily Rainfall Comparison - Accra_Aca, Accra_Girls, St_Johns',
    labels=['Accra_Aca', 'Accra_Girls', 'St_Johns']
)

# %%
print_precip_stats(accra_aca_merged_r1_copy)
print("")
print_precip_stats(accra_girls_merged_r1_copy)
print("")
print_precip_stats(st_johns_merged_r1_copy)
# Out:
# Mean of Interpol_Precip: 0.14
# Standard Deviation of Interpol_Precip: 1.99
#
# Mean of Interpol_Precip: 0.06
# Standard Deviation of Interpol_Precip: 1.07
#
# Mean of Interpol_Precip: 0.08
# Standard Deviation of Interpol_Precip: 1.32

# %%
calc_precip_corr_three(accra_aca_merged_r1_copy, accra_girls_merged_r1_copy, st_johns_merged_r1_copy)
# Out:
# Correlation between df1 and df2: 0.436
# Correlation between df1 and df3: 0.530
# Correlation between df2 and df3: 0.535

# %%
run_ttest(accra_aca_merged_r1_copy, accra_girls_merged_r1_copy, column='Interpol_Precip')
# Out:
# t-test comparing DF1 and DF2 on 'Interpol_Precip':
#   t-statistic: 3.927
#   p-value: 0.000
#   ✅ Statistically significant difference in means.

# %%
run_ttest(accra_aca_merged_r1_copy, st_johns_merged_r1_copy, column='Interpol_Precip')
# Out:
# t-test comparing DF1 and DF2 on 'Interpol_Precip':
#   t-statistic: 2.661
#   p-value: 0.008
#   ✅ Statistically significant difference in means.

# %%
run_ttest(accra_girls_merged_r1_copy, st_johns_merged_r1_copy, column='Interpol_Precip')
# Out:
# t-test comparing DF1 and DF2 on 'Interpol_Precip':
#   t-statistic: -1.446
#   p-value: 0.148
#   ❌ No statistically significant difference in means.

# %%
resample_and_plot_temp_multi(
    df1=accra_aca_merged_r1_copy,
    df2=accra_girls_merged_r1_copy,
    df3=st_johns_merged_r1_copy,
    freq='D',
    title='Daily Temperature Comparison - Accra_Aca, Accra_Girls, St_Johns',
    labels=['Accra_Aca', 'Accra_Girls', 'St_Johns']
)

# %% [markdown]
# #### Temasco, Safisana

# %%
temasco_merged_r1_copy = temasco_merged_r1.copy()
temasco_merged_r1_copy = temasco_merged_r1_copy.set_index('Hour').loc['2022':'2023'].reset_index()

safisana_merged_r1_copy = safisana_merged_r1.copy()
safisana_merged_r1_copy = safisana_merged_r1_copy.set_index('Hour').loc['2022':'2023-06-29 13:00:00'].reset_index()

# %%
## Distance between them: 
# Temasco & Safisana - 6.26 km

# %%
resample_and_plot_precip_multi(
    df1=temasco_merged_r1_copy,
    df2=safisana_merged_r1_copy,
    freq='D',
    title='Daily Rainfall Comparison - Temasco, Safisana',
    labels=['Temasco', 'Safisana']
)

# %%
run_ttest(temasco_merged_r1_copy, safisana_merged_r1_copy, column='Interpol_Precip', label1='Temasco', label2='Safisana')
# Out:
# t-test comparing Temasco and Safisana on 'Interpol_Precip':
#   t-statistic: -0.718
#   p-value: 0.473
#   ❌ No statistically significant difference in means.

# %%
resample_and_plot_temp_multi(
    df1=temasco_merged_r1_copy,
    df2=safisana_merged_r1_copy,
    freq='D',
    title='Daily Temp Comparison - Temasco, Safisana',
    labels=['Temasco', 'Safisana']
)

# %%
print_precip_stats(temasco_merged_r1_copy)
print("")
print_precip_stats(safisana_merged_r1_copy)
# Out:
# Mean of Interpol_Precip: 0.06
# Standard Deviation of Interpol_Precip: 0.73
#
# Mean of Interpol_Precip: 0.06
# Standard Deviation of Interpol_Precip: 0.77

# %%
calc_precip_corr(temasco_merged_r1_copy, safisana_merged_r1_copy)
# Out:
# Correlation between Interpol_Precip in the two DataFrames: 0.293
